# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Charger tous les CSV
movies = pd.read_csv("data/csv/movies.csv")
persons = pd.read_csv("data/csv/persons.csv")
genres = pd.read_csv("data/csv/genres.csv")
ratings = pd.read_csv("data/csv/ratings.csv")
principals = pd.read_csv("data/csv/principals.csv")
titles = pd.read_csv("data/csv/titles.csv")
directors = pd.read_csv("data/csv/directors.csv")
writers = pd.read_csv("data/csv/writers.csv")
characters = pd.read_csv("data/csv/characters.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Charger tous les CSV
# ----> 4 movies = pd.read_csv("data/csv/movies.csv")
#       5 persons = pd.read_csv("data/csv/persons.csv")
#       6 genres = pd.read_csv("data/csv/genres.csv")
#
# ...

# %%
import pandas as pd

# Charger tous les CSV
movies = pd.read_csv("data/movies.csv")
persons = pd.read_csv("data/persons.csv")
genres = pd.read_csv("data/genres.csv")
ratings = pd.read_csv("data/ratings.csv")
principals = pd.read_csv("data/principals.csv")
titles = pd.read_csv("data/titles.csv")
directors = pd.read_csv("data/directors.csv")
writers = pd.read_csv("data/writers.csv")
characters = pd.read_csv("data/characters.csv")

# %%
movies.head()
# Out:
#     ('mid',) ('titleType',)                          ('primaryTitle',)  \
# 0  tt0002130          movie                            Dante's Inferno
# 1  tt0002844          movie  Fantômas: In the Shadow of the Guillotine
# 2  tt0003014          movie                              Ingeborg Holm
# 3  tt0003037          movie                 Fantomas: The Man in Black
# 4  tt0003165          movie          Fantômas: The Dead Man Who Killed
#
#                       ('originalTitle',)  ('isAdult',)  ('startYear',)  \
# 0                              L'Inferno             0            1911
# 1  Fantômas - À l'ombre de la guillotine             0            1913
# 2                          Ingeborg Holm             0            1913
# 3                   Juve contre Fantômas             0            1913
# 4                        Le mort qui tue             0            1913
#
#    ('endYear',)  ('runtimeMinutes',)
# 0           NaN                 71.0
# ...
